# %%
import pandas as pd

# %%
my_input = [2,3,4,5]
list_manipulation = my_input*2
print(list_manipulation)
# Out:
# [2, 3, 4, 5, 2, 3, 4, 5]

# %%
my_dimension = pd.DataFrame(my_input)

# %%
print(my_dimension)
# Out:
#    0
# 0  2
# 1  3
# 2  4
# 3  5

# %%
print(type(my_dimension))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
my_list = [[1,2,3,4],[5,6,7,8]]
my_list
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
pandas_frame = pd.DataFrame(my_list)
pandas_frame
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %%
sum_of_list = pandas_frame.sum(axis = 1)
print(sum_of_list)
# Out:
# 0    10
# 1    26
# dtype: int64

# %%
my_list = [[1,'s',3,4],['a','b',7,8]]
my_list
# Out:
# [[1, 's', 3, 4], ['a', 'b', 7, 8]]

# %%
pandas_frame = pd.DataFrame(my_list)
pandas_frame
# Out:
#    0  1  2  3
# 0  1  s  3  4
# 1  a  b  7  8

# %%
my_tuple = (1,2,3,4)
my_tuple
pandas_frame = pd.DataFrame(my_tuple)
pandas_frame
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
my_dict = {1:[1],2:[32]}
pandas_frame = pd.DataFrame(my_dict)
pandas_frame
# Out:
#    1   2
# 0  1  32

# %%
my_list = [[1,2,3,4],[5,6,7,8]]

pandas_frame = pd.DataFrame(my_list, index=["a","b"],columns= ["A","B","C","D"])
pandas_frame
# Out:
#    A  B  C  D
# a  1  2  3  4
# b  5  6  7  8

# %%
my_dict = {"names":["dhoni","kohli"],"team":["csk","rcb"]}
my_frame = pd.DataFrame(my_dict,index = ["a","b"])
print(my_frame)
# Out:
#    names team
# a  dhoni  csk
# b  kohli  rcb

# %%
my_dict = {"names":["dhoni","kohli"],"team":["csk","rcb"]}
my_frame = pd.DataFrame(my_dict,index = ["a","b"],columns= ["A","B","C","D"])
print(my_frame)
# Out:
#      A    B    C    D
# a  NaN  NaN  NaN  NaN
# b  NaN  NaN  NaN  NaN

# %%
my_dict = {"names":["dhoni","kohli"],"team":["csk","rcb"]}
my_frame = pd.DataFrame(my_dict,index = ["a","b"])
print(my_frame)
# Out:
#    names team
# a  dhoni  csk
# b  kohli  rcb

# %%
print(my_frame.loc["a"])
# Out:
# names    dhoni
# team       csk
# Name: a, dtype: object

# %%
print(my_frame.iloc[0,0])
# Out:
# dhoni

# %%
print(my_frame.iloc[0:])
# Out:
#    names team
# a  dhoni  csk
# b  kohli  rcb

# %%
my_frame.to_csv("testing.csv")

# %%
print(my_frame.iloc[0:1])
# Out:
#    names team
# a  dhoni  csk

# %%
print(my_frame.iloc[:])
# Out:
#    names team
# a  dhoni  csk
# b  kohli  rcb

# %% [markdown]
# Group BY :--

# %%
# importing pandas as pd
import pandas as pd
  
# Creating the dataframe 
df = pd.read_csv("nba.csv")
  
# Print the dataframe
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# applying groupby() function to
# group the data on team value.
gk = df.groupby('Team')

# Let's print the first entries
# in all the groups formed.
gk.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %%
# Finding the values contained in the "Boston Celtics" group
gk.get_group('Boston Celtics')
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %% [markdown]
# example 2:-

# %%
# importing pandas as pd
import pandas as pd

# Creating the dataframe
df = pd.read_csv("nba.csv")

# First grouping based on "Team"
# Within each team we are grouping based on "Position"
gkk = df.groupby(['Team', 'Position'])

# Print the first value in each group
gkk.first()
# Out:
#                                          Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford    15.0  30.0   6-10   245.0
#                    PF          Kris Humphries    43.0  31.0    6-9   235.0
#                    PG         Dennis Schroder    17.0  22.0    6-1   172.0
#                    SF           Kent Bazemore    24.0  26.0    6-5   201.0
#                    SG        Tim Hardaway Jr.    10.0  24.0    6-6   205.0
# ...                                       ...     ...   ...    ...     ...
# Washington Wizards C            Marcin Gortat    13.0  32.0   6-11   240.0
#                    PF             Drew Gooden    90.0  34.0   6-10   250.0
#                    PG          Ramon Sessions     7.0  30.0    6-3   190.0
#                    SF            Jared Dudley     1.0  30.0    6-7   225.0
#                    SG           Alan Anderson     6.0  33.0    6-6   220.0
#
# ...

# %% [markdown]
# Practicse some group by :-

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA']}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
# using groupby function
# with one key

df.groupby('Name')
print(df.groupby('Name').groups)
# Out:
# {'Abhi': [7], 'Anuj': [1, 5], 'Gaurav': [4], 'Jai': [0, 2], 'Princi': [3, 6]}

# %%
# applying groupby() function to
# group the data on Name value.
gk = df.groupby('Name')

# Let's print the first entries
# in all the groups formed.
gk.first()
# Out:
#         Age  Address Qualification
# Name
# Abhi     32  Aligarh            MA
# Anuj     24   Kanpur            MA
# Gaurav   33  Jaunpur        B.Tech
# Jai      27   Nagpur           Msc
# Princi   32  Kannuaj           Phd

# %% [markdown]
# group by using multiple arguments :-

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA']}
	

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
# Using multiple keys in
# groupby() function
df.groupby(['Name', 'Qualification'])

print(df.groupby(['Name', 'Qualification']).groups)
# Out:
# {('Abhi', 'MA'): [7], ('Anuj', 'B.com'): [5], ('Anuj', 'MA'): [1], ('Gaurav', 'B.Tech'): [4], ('Jai', 'MCA'): [2], ('Jai', 'Msc'): [0], ('Princi', 'Msc'): [6], ('Princi', 'Phd'): [3]}

# %%
data = {"score":[90,20,25,36],"player":["dhoni","dhoni","kohli","pandya"]}
df_data = pd.DataFrame(data)
df_data
# Out:
#    score  player
# 0     90   dhoni
# 1     20   dhoni
# 2     25   kohli
# 3     36  pandya

# %%
mean_data = df_data.groupby(['player']).mean()

# %%
mean_data
# Out:
#         score
# player
# dhoni    55.0
# kohli    25.0
# pandya   36.0

# %%
data = {"runs":[1,2,3,4],"score":[90,20,25,36],"player":["dhoni","dhoni","kohli","pandya"]}
df_data = pd.DataFrame(data)
df_data
# Out:
#    runs  score  player
# 0     1     90   dhoni
# 1     2     20   dhoni
# 2     3     25   kohli
# 3     4     36  pandya

# %%
mean_data = df_data.groupby(['player']).mean()
mean_data
# Out:
#         runs  score
# player
# dhoni    1.5   55.0
# kohli    3.0   25.0
# pandya   4.0   36.0

# %%
mean_data = df_data.groupby(['player'])["runs"].mean()
mean_data
# Out:
# player
# dhoni     1.5
# kohli     3.0
# pandya    4.0
# Name: runs, dtype: float64

# %%
data = {"grade": ["A","A","B","D"] , "runs":[1,2,3,4],"score":[90,20,25,36],"player":["dhoni","dhoni","kohli","pandya"]}
df_data = pd.DataFrame(data)
df_data
# Out:
#   grade  runs  score  player
# 0     A     1     90   dhoni
# 1     A     2     20   dhoni
# 2     B     3     25   kohli
# 3     D     4     36  pandya

# %%
mean_data = df_data.groupby(['player']).mean()
mean_data
# Out:
#         runs  score
# player
# dhoni    1.5   55.0
# kohli    3.0   25.0
# pandya   4.0   36.0

# %%
df_data.sort_values("score")
# Out:
#   grade  runs  score  player
# 1     A     2     20   dhoni
# 2     B     3     25   kohli
# 3     D     4     36  pandya
# 0     A     1     90   dhoni
