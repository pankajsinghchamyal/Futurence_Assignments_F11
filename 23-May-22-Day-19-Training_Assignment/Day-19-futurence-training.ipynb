# %% [markdown]
# # Problem 1

# %%
s = "AABCAAADA"
k = 3
n = len(s)
split = n/k
result = []
res = ""
j = 0

while n>0:
    
    n-=1
    res +=s[j]
    if len(res) == split:
        result.append(res)
        res = ""
    j+=1

# for value in result:
#     print("".join(set(value)))

display = ""
for value in result:
    i = 0
    size = len(value)
    while size > 0:
        size -=1
        if value[i] not in display:
            
            display += value[i]
        i+=1
    
    print(display)
    display = ""
# Out:
# AB
# CA
# AD

# %% [markdown]
# # Problem 2

# %%
year = 2000

if (year%400 == 0 and year%100 == 0) or ((year % 4 ==0) and (year % 100 != 0)):
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# # Problem 3

# %%
# Alphabet Rangoli in Python - HackerRank Solution
def print_rangoli(size):
    # your code goes here
    # Alphabet Rangoli in Python - HackerRank Solution START
    width  = size*4-3
    string = ''

    for i in range(1,size+1):
        for j in range(0,i):
            string += chr(96+size-j)
            if len(string) < width :
                string += '-'
        for k in range(i-1,0,-1):    
            string += chr(97+size-k)
            if len(string) < width :
                string += '-'
        print(string.center(width,'-'))
        string = ''

    for i in range(size-1,0,-1):
        string = ''
        for j in range(0,i):
            string += chr(96+size-j)
            if len(string) < width :
                string += '-'
        for k in range(i-1,0,-1):
            string += chr(97+size-k)
            if len(string) < width :
                string += '-'
        print(string.center(width,'-'))
        
    # Alphabet Rangoli in Python - HackerRank Solution END

if __name__ == '__main__':
    n = int(input())
    print_rangoli(n)
# Out:
#  5
# --------e--------
# ------e-d-e------
# ----e-d-c-d-e----
# --e-d-c-b-c-d-e--
# e-d-c-b-a-b-c-d-e
# --e-d-c-b-c-d-e--
# ----e-d-c-d-e----
# ------e-d-e------
# --------e--------

# %%
txt = "banana"

x = txt.center(20)
x
# Out:
# '       banana       '

# %%
import pandas as pd

# %%
sales = pd.read_csv("5m Sales Records.csv",parse_dates=["Order Date","Ship Date"],infer_datetime_format = True)

# %%
sales.head()
# Out:
#                          Region  Country        Item Type Sales Channel  \
# 0         Australia and Oceania    Palau  Office Supplies        Online
# 1                        Europe   Poland        Beverages        Online
# 2                 North America   Canada           Cereal        Online
# 3                        Europe  Belarus           Snacks        Online
# 4  Middle East and North Africa     Oman           Cereal       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H 2016-03-06  517073523 2016-03-26        2401      651.21
# 1              L 2010-04-18  380507028 2010-05-26        9340       47.45
# 2              M 2015-01-08  504055583 2015-01-31         103      205.70
# 3              C 2014-01-19  954955518 2014-02-27        1414      152.58
# 4              H 2019-04-26  970755660 2019-06-02        7027      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
#sales.to_string()

# %%
sales.describe()
# Out:
#            Order ID    Units Sold    Unit Price     Unit Cost  Total Revenue  \
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06   5.000000e+06
# mean   5.498905e+08  4.999991e+03  2.661906e+02  1.876560e+02   1.331058e+06
# std    2.597753e+08  2.886787e+03  2.170153e+02  1.757014e+02   1.469902e+06
# min    1.000003e+08  1.000000e+00  9.330000e+00  6.920000e+00   9.330000e+00
# 25%    3.249650e+08  2.500000e+03  1.092800e+02  5.667000e+01   2.779637e+05
# 50%    5.497643e+08  4.999000e+03  2.057000e+02  1.171100e+02   7.859797e+05
# 75%    7.748374e+08  7.500000e+03  4.372000e+02  3.646900e+02   1.822444e+06
# max    9.999999e+08  1.000000e+04  6.682700e+02  5.249600e+02   6.682700e+06
#
#          Total Cost  Total Profit
# count  5.000000e+06  5.000000e+06
# mean   9.383781e+05  3.926799e+05
# std    1.150104e+06  3.791169e+05
# min    6.920000e+00  2.410000e+00
# 25%    1.619251e+05  9.514566e+04
# 50%    4.677120e+05  2.816551e+05
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   Item Type       object
#  3   Sales Channel   object
#  4   Order Priority  object
#  5   Order Date      datetime64[ns]
#  6   Order ID        int64
#  7   Ship Date       datetime64[ns]
#  8   Units Sold      int64
#  9   Unit Price      float64
#  10  Unit Cost       float64
#  11  Total Revenue   float64
#  12  Total Cost      float64
#  13  Total Profit    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 534.1+ MB

# %%
pd.set_option('display.max_rows', 1000)

# %%
sales
# Out:
#                                Region           Country        Item Type  \
# 0               Australia and Oceania             Palau  Office Supplies
# 1                              Europe            Poland        Beverages
# 2                       North America            Canada           Cereal
# 3                              Europe           Belarus           Snacks
# 4        Middle East and North Africa              Oman           Cereal
# ...                               ...               ...              ...
# 4999995  Middle East and North Africa              Iraq        Household
# 4999996                        Europe            Monaco             Meat
# 4999997         Australia and Oceania   Solomon Islands          Clothes
# 4999998         Australia and Oceania  Marshall Islands        Cosmetics
# 4999999                        Europe            Greece  Office Supplies
#
#         Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %%
df_Country = sales['Country'].unique

# %%
df_Country
# Out:
# <bound method Series.unique of 0                     Palau
# 1                    Poland
# 2                    Canada
# 3                   Belarus
# 4                      Oman
#                  ...
# 4999995                Iraq
# 4999996              Monaco
# 4999997     Solomon Islands
# 4999998    Marshall Islands
# 4999999              Greece
# Name: Country, Length: 5000000, dtype: object>
